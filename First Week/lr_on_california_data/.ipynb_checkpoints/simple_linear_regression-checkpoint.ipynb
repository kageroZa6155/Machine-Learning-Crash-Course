# %%
import numpy as np
import pandas as pd 
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline


# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.2f}".format

# %%
# Import the dataset.
train_df = pd.read_csv(filepath_or_buffer="https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")
test_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_test.csv")

# %%
scale_factor = 1000.0

# Scale the training set's label.
train_df["median_house_value"] /= scale_factor 

# Scale the test set's label
test_df["median_house_value"] /= scale_factor

train_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19               15.00      5612.00         1283.00
# 1    -114.47     34.40               19.00      7650.00         1901.00
# 2    -114.56     33.69               17.00       720.00          174.00
# 3    -114.57     33.64               14.00      1501.00          337.00
# 4    -114.57     33.57               20.00      1454.00          326.00
#
#    population  households  median_income  median_house_value
# 0     1015.00      472.00           1.49               66.90
# 1     1129.00      463.00           1.82               80.10
# 2      333.00      117.00           1.65               85.70
# 3      515.00      226.00           3.19               73.40
# 4      624.00      262.00           1.93               65.50

# %% [markdown]
# Scaling ***median_house_value*** puts the value of each house in units of thousands. Scaling will keep loss values and learning rates in a friendlier range.
#
# Although *scaling* a label is ***usually not essential***, ***scaling features in a multi-feature model usually is essential.***

# %% [markdown]
# #### ***Examine Data***

# %%
train_df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count   17000.00  17000.00            17000.00     17000.00        17000.00
# mean     -119.56     35.63               28.59      2643.66          539.41
# std         2.01      2.14               12.59      2179.95          421.50
# min      -124.35     32.54                1.00         2.00            1.00
# 25%      -121.79     33.93               18.00      1462.00          297.00
# 50%      -118.49     34.25               29.00      2127.00          434.00
# 75%      -118.00     37.72               37.00      3151.25          648.25
# max      -114.31     41.95               52.00     37937.00         6445.00
#
#        population  households  median_income  median_house_value
# count    17000.00    17000.00       17000.00            17000.00
# mean      1429.57      501.22           3.88              207.30
# std       1147.85      384.52           1.91              115.98
# min          3.00        1.00           0.50               15.00
# 25%        790.00      282.00           2.57              119.40
# 50%       1167.00      409.00           3.54              180.40
# 75%       1721.00      605.25           4.77              265.00
# max      35682.00     6082.00          15.00              500.00

# %% [markdown]
# * total_rooms, total_bedrooms, population, and households
# > There is a huge gap between upper quantile and the max value.
# > Especially in ***total_rooms*** and the ***population*** fields.
#
# We can consider these values as outlier. And discard those from data.

# %%
# %%time

### Defining the model and training functions
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
    """Create and compile a simple linear regression model."""
    # Most simple tf.keras models are sequential.
    model = tf.keras.models.Sequential()

    # Describe the topography of the model.
    # The topography of a simple linear regression model
    # is a single node in a single layer.
    model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))

    # Compile the model topography into code that TensorFlow can efficiently
    # execute. Configure training to minimize the model's mean squared error. 
    model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

    return model        


def train_model(model, df, feature, label, epochs, batch_size = None, validation_split=.1):
    """Train the model by feeding it data."""

    # Feed the model the feature and the label.
    # The model will train for the specified number of epochs. 
    history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs,
                      validation_split=validation_split)

    # Gather the trained model's weight and bias.
    weight = model.get_weights()[0]
    intercept = model.get_weights()[1] # the scalar where intercept the y-axis when the all weights are equal to zero.

    # The list of epochs is stored separately from the rest of history.
    epochs = history.epoch
  
    # Isolate the error for each epoch.
    hist = pd.DataFrame(history.history)

#     # To track the progression of training, we're going to take a snapshot
#     # of the model's root mean squared error at each epoch. 
#     rmse = hist["root_mean_squared_error"]
    # Isolate the root mean squared error for each epoch.
    hist = pd.DataFrame(history.history)
    rmse = hist["root_mean_squared_error"]

    return  epochs, rmse, history.history # weight, intercept, epochs, rmse

print("Model functions are defined...")
# Out:
# Model functions are defined...
# Wall time: 997 µs

# %%
# %%time
#@title Define the plotting function

def plot_the_loss_curve(epochs, mae_training, mae_validation):
    """Plot a curve of loss vs. epoch."""

    plt.figure(figsize=(12,7))
    plt.xlabel("Epoch")
    plt.ylabel("Root Mean Squared Error")

    plt.plot(epochs[1:], mae_training[1:], label="Training Loss")
    plt.plot(epochs[1:], mae_validation[1:], label="Validation Loss")
    plt.legend()
  
    # We're not going to plot the first epoch, since the loss on the first epoch
    # is often substantially greater than the loss for other epochs.
    merged_mae_lists = mae_training[1:] + mae_validation[1:]
    highest_loss = max(merged_mae_lists)
    lowest_loss = min(merged_mae_lists)
    delta = highest_loss - lowest_loss
    print(delta)

    top_of_y_axis = highest_loss + (delta * 0.05)
    bottom_of_y_axis = lowest_loss - (delta * 0.05)
   
    plt.ylim([bottom_of_y_axis, top_of_y_axis])
    plt.yticks(np.arange(bottom_of_y_axis, top_of_y_axis+.5, 5))
    plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.
# Wall time: 0 ns

# %%
#@title Define Evaluation function
def evaluate(df, X, y, learning_rate=.01, epochs=3, batch_size=None, validation_rate=.2, evaluate_test_set = False, test_df=None):
    """
    Evaluates the ML process.
    X array like list of feature headers. ["feature_1", "feature_2", "feature_3", ...]
    y target variable's header.
    """
    # Invoke the functions to build and train the model.
    model = build_model(learning_rate)
    epochs, rmse, history = train_model(model, df, X, y, 
                                        epochs, batch_size, 
                                        validation_rate)
    
    
        
    plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                        history["val_root_mean_squared_error"])
    
    if evaluate_test_set:
        x_test = test_df[X]
        y_test = test_df[y]

        results = model.evaluate(x_test, y_test, batch_size=batch_size)
        print("*"*24)
        print("Test Results")
        print("*"*24)
        print("Loss: {},\nRMSE: {}".format(results[0], results[1]))
        print("*"*24)

# %%
### Task 1 - Experimenting with Validation Split
evaluate(train_df, ["median_income"], "median_house_value", 0.08, 30, 100, .2)
# Out:
# Train on 13600 samples, validate on 3400 samples
# Epoch 1/30
# 13600/13600 [==============================] - 0s 35us/sample - loss: 39290.4758 - root_mean_squared_error: 198.2182 - val_loss: 47688.9609 - val_root_mean_squared_error: 218.3780
# Epoch 2/30
# 13600/13600 [==============================] - 0s 12us/sample - loss: 22544.8571 - root_mean_squared_error: 150.1494 - val_loss: 27756.0599 - val_root_mean_squared_error: 166.6015
# Epoch 3/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 11929.4254 - root_mean_squared_error: 109.2219 - val_loss: 15026.1946 - val_root_mean_squared_error: 122.5814
# Epoch 4/30
# 13600/13600 [==============================] - 0s 12us/sample - loss: 7178.0084 - root_mean_squared_error: 84.7231 - val_loss: 9547.2902 - val_root_mean_squared_error: 97.7102
# Epoch 5/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6513.7715 - root_mean_squared_error: 80.7079 - val_loss: 9340.8298 - val_root_mean_squared_error: 96.6480
# Epoch 6/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6514.3277 - root_mean_squared_error: 80.7114 - val_loss: 9265.6764 - val_root_mean_squared_error: 96.2584
# Epoch 7/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6513.9603 - root_mean_squared_error: 80.7091 - val_loss: 9343.1545 - val_root_mean_squared_error: 96.6600
# Epoch 8/30
# 13600/13600 [==============================] - ETA: 0s - loss: 6542.2264 - root_mean_squared_error: 80.884 - 0s 13us/sample - loss: 6513.5448 - root_mean_squared_error: 80.7065 - val_loss: 9380.2581 - val_root_mean_squared_error: 96.8517
# Epoch 9/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6513.0484 - root_mean_squared_error: 80.7035 - val_loss: 9162.1490 - val_root_mean_squared_error: 95.7191
# Epoch 10/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6513.4644 - root_mean_squared_error: 80.7060 - val_loss: 9393.4183 - val_root_mean_squared_error: 96.9196
# Epoch 11/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6513.6250 - root_mean_squared_error: 80.7070 - val_loss: 9289.7078 - val_root_mean_squared_error: 96.3831
# Epoch 12/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6513.3862 - root_mean_squared_error: 80.7056 - val_loss: 9289.4624 - val_root_mean_squared_error: 96.3819
# Epoch 13/30
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6511.7645 - root_mean_squared_error: 80.6955 - val_loss: 9375.9144 - val_root_mean_squared_error: 96.8293
# Epoch 14/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6512.8228 - root_mean_squared_error: 80.7021 - val_loss: 9180.0926 - val_root_mean_squared_error: 95.8128
# Epoch 15/30
# 13600/13600 [==============================] - 0s 16us/sample - loss: 6512.3835 - root_mean_squared_error: 80.6993 - val_loss: 9287.5654 - val_root_mean_squared_error: 96.3720
# Epoch 16/30
# 13600/13600 [==============================] - 0s 16us/sample - loss: 6513.8737 - root_mean_squared_error: 80.7086 - val_loss: 9393.5638 - val_root_mean_squared_error: 96.9204
# Epoch 17/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6514.1262 - root_mean_squared_error: 80.7101 - val_loss: 9257.6746 - val_root_mean_squared_error: 96.2168
# Epoch 18/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6513.8030 - root_mean_squared_error: 80.7081 - val_loss: 9259.9716 - val_root_mean_squared_error: 96.2287
# Epoch 19/30
# 13600/13600 [==============================] - 0s 16us/sample - loss: 6513.7463 - root_mean_squared_error: 80.7078 - val_loss: 9241.2633 - val_root_mean_squared_error: 96.1315
# Epoch 20/30
# 13600/13600 [==============================] - 0s 14us/sample - loss: 6514.5826 - root_mean_squared_error: 80.7130 - val_loss: 9233.1098 - val_root_mean_squared_error: 96.0891
# Epoch 21/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6512.0203 - root_mean_squared_error: 80.6971 - val_loss: 9252.4958 - val_root_mean_squared_error: 96.1899
# Epoch 22/30
# 13600/13600 [==============================] - 0s 14us/sample - loss: 6514.2186 - root_mean_squared_error: 80.7107 - val_loss: 9251.2323 - val_root_mean_squared_error: 96.1833
# Epoch 23/30
# 13600/13600 [==============================] - 0s 15us/sample - loss: 6514.2082 - root_mean_squared_error: 80.7106 - val_loss: 9241.8164 - val_root_mean_squared_error: 96.1344
# Epoch 24/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6512.9649 - root_mean_squared_error: 80.7030 - val_loss: 9236.0015 - val_root_mean_squared_error: 96.1041
# Epoch 25/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6514.3519 - root_mean_squared_error: 80.7115 - val_loss: 9256.6825 - val_root_mean_squared_error: 96.2117
# Epoch 26/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6513.2121 - root_mean_squared_error: 80.7045 - val_loss: 9360.1052 - val_root_mean_squared_error: 96.7476
# Epoch 27/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6512.9715 - root_mean_squared_error: 80.7030 - val_loss: 9359.0172 - val_root_mean_squared_error: 96.7420
# Epoch 28/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6513.6787 - root_mean_squared_error: 80.7074 - val_loss: 9227.7476 - val_root_mean_squared_error: 96.0612
# Epoch 29/30
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6510.5288 - root_mean_squared_error: 80.6878 - val_loss: 9132.0570 - val_root_mean_squared_error: 95.5618
# Epoch 30/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6514.0375 - root_mean_squared_error: 80.7096 - val_loss: 9238.7611 - val_root_mean_squared_error: 96.1185
# 85.91366

# %% [markdown]
# By changing validation set size, we can get the expected results, Nearly equal train and validation loss.
# as we can see the train and validation losses differ from each other. But why?

# %%
### Task 2 - Searching the reason **why** the train and val. losses differ from each other.
train_df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19               15.00      5612.00         1283.00
# 1    -114.47     34.40               19.00      7650.00         1901.00
# 2    -114.56     33.69               17.00       720.00          174.00
# 3    -114.57     33.64               14.00      1501.00          337.00
# 4    -114.57     33.57               20.00      1454.00          326.00
# 5    -114.58     33.63               29.00      1387.00          236.00
# 6    -114.58     33.61               25.00      2907.00          680.00
# 7    -114.59     34.83               41.00       812.00          168.00
# 8    -114.59     33.61               34.00      4789.00         1175.00
# 9    -114.60     34.83               46.00      1497.00          309.00
#
#    population  households  median_income  median_house_value
# 0     1015.00      472.00           1.49               66.90
# 1     1129.00      463.00           1.82               80.10
# 2      333.00      117.00           1.65               85.70
# 3      515.00      226.00           3.19               73.40
# 4      624.00      262.00           1.93               65.50
# 5      671.00      239.00           3.34               74.00
# 6     1841.00      633.00           2.68               82.40
# 7      375.00      158.00           1.71               48.50
# 8     3134.00     1056.00           2.18               58.40
# 9      787.00      271.00           2.19               48.10

# %%
train_df.tail(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16990    -124.22     41.73               28.00      3003.00          699.00
# 16991    -124.23     41.75               11.00      3159.00          616.00
# 16992    -124.23     40.81               52.00      1112.00          209.00
# 16993    -124.23     40.54               52.00      2694.00          453.00
# 16994    -124.25     40.28               32.00      1430.00          419.00
# 16995    -124.26     40.58               52.00      2217.00          394.00
# 16996    -124.27     40.69               36.00      2349.00          528.00
# 16997    -124.30     41.84               17.00      2677.00          531.00
# 16998    -124.30     41.80               19.00      2672.00          552.00
# 16999    -124.35     40.54               52.00      1820.00          300.00
#
#        population  households  median_income  median_house_value
# 16990     1530.00      653.00           1.70               78.30
# 16991     1343.00      479.00           2.48               73.20
# 16992      544.00      172.00           3.35               50.80
# 16993     1152.00      435.00           3.08              106.70
# 16994      434.00      187.00           1.94               76.10
# 16995      907.00      369.00           2.36              111.40
# 16996     1194.00      465.00           2.52               79.00
# 16997     1244.00      456.00           3.03              103.60
# 16998     1298.00      478.00           1.98               85.80
# 16999      806.00      270.00           3.01               94.60

# %%
train_df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude                1.00     -0.93               -0.11         0.05
# latitude                -0.93      1.00                0.02        -0.04
# housing_median_age      -0.11      0.02                1.00        -0.36
# total_rooms              0.05     -0.04               -0.36         1.00
# total_bedrooms           0.07     -0.07               -0.32         0.93
# population               0.10     -0.11               -0.30         0.86
# households               0.06     -0.07               -0.30         0.92
# median_income           -0.02     -0.08               -0.12         0.20
# median_house_value      -0.04     -0.14                0.11         0.13
#
#                     total_bedrooms  population  households  median_income  \
# longitude                     0.07        0.10        0.06          -0.02
# latitude                     -0.07       -0.11       -0.07          -0.08
# housing_median_age           -0.32       -0.30       -0.30          -0.12
# total_rooms                   0.93        0.86        0.92           0.20
# total_bedrooms                1.00        0.88        0.98          -0.01
# population                    0.88        1.00        0.91          -0.00
# households                    0.98        0.91        1.00           0.01
# median_income                -0.01       -0.00        0.01           1.00
# median_house_value            0.05       -0.03        0.06           0.69
#
#                     median_house_value
# longitude                        -0.04
# latitude                         -0.14
# housing_median_age                0.11
# total_rooms                       0.13
# total_bedrooms                    0.05
# population                       -0.03
# households                        0.06
# median_income                     0.69
# median_house_value                1.00

# %% [markdown]
# The train_df is sorted by the **logitude** feature, and this feature has a effect on the **median_income** and the **median_house_value**. We may consider adding this feature to our model but since we are studying on Simple Lineer Regression, We'll just shuffle the train data.

# %%
### Task 3 - Fixing The Problem.
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index))
evaluate(shuffled_train_df, ["median_income"], "median_house_value", 0.08, 70, 100, .2)
# Out:
# Train on 13600 samples, validate on 3400 samples
# Epoch 1/70
# 13600/13600 [==============================] - 0s 31us/sample - loss: 45799.6159 - root_mean_squared_error: 214.0085 - val_loss: 37839.7526 - val_root_mean_squared_error: 194.5244
# Epoch 2/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 27148.0416 - root_mean_squared_error: 164.7666 - val_loss: 21348.7636 - val_root_mean_squared_error: 146.1122
# Epoch 3/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 14646.7828 - root_mean_squared_error: 121.0239 - val_loss: 11330.5939 - val_root_mean_squared_error: 106.4453
# Epoch 4/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 8336.2770 - root_mean_squared_error: 91.3032 - val_loss: 7568.8752 - val_root_mean_squared_error: 86.9993
# Epoch 5/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6937.4587 - root_mean_squared_error: 83.2914 - val_loss: 7404.9122 - val_root_mean_squared_error: 86.0518
# Epoch 6/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6916.8016 - root_mean_squared_error: 83.1673 - val_loss: 7401.7446 - val_root_mean_squared_error: 86.0334
# Epoch 7/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.8949 - root_mean_squared_error: 83.1739 - val_loss: 7402.7644 - val_root_mean_squared_error: 86.0393
# Epoch 8/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6916.7152 - root_mean_squared_error: 83.1668 - val_loss: 7403.3118 - val_root_mean_squared_error: 86.0425
# Epoch 9/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6916.6125 - root_mean_squared_error: 83.1662 - val_loss: 7405.2619 - val_root_mean_squared_error: 86.0538
# Epoch 10/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.2052 - root_mean_squared_error: 83.1697 - val_loss: 7401.9835 - val_root_mean_squared_error: 86.0348
# Epoch 11/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.5012 - root_mean_squared_error: 83.1715 - val_loss: 7404.5973 - val_root_mean_squared_error: 86.0500
# Epoch 12/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6918.1479 - root_mean_squared_error: 83.1754 - val_loss: 7403.4448 - val_root_mean_squared_error: 86.0433
# Epoch 13/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.7760 - root_mean_squared_error: 83.1732 - val_loss: 7402.6387 - val_root_mean_squared_error: 86.0386
# Epoch 14/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.3166 - root_mean_squared_error: 83.1704 - val_loss: 7402.3710 - val_root_mean_squared_error: 86.0370
# Epoch 15/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6916.8055 - root_mean_squared_error: 83.1673 - val_loss: 7402.5000 - val_root_mean_squared_error: 86.0378
# Epoch 16/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6918.0030 - root_mean_squared_error: 83.1745 - val_loss: 7405.4553 - val_root_mean_squared_error: 86.0550
# Epoch 17/70
# 13600/13600 [==============================] - 0s 16us/sample - loss: 6917.2318 - root_mean_squared_error: 83.1699 - val_loss: 7404.4898 - val_root_mean_squared_error: 86.0493
# Epoch 18/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 6917.4583 - root_mean_squared_error: 83.1713 - val_loss: 7407.4548 - val_root_mean_squared_error: 86.0666
# Epoch 19/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.8287 - root_mean_squared_error: 83.1735 - val_loss: 7403.9144 - val_root_mean_squared_error: 86.0460
# Epoch 20/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.9043 - root_mean_squared_error: 83.1739 - val_loss: 7402.8855 - val_root_mean_squared_error: 86.0400
# Epoch 21/70
# 13600/13600 [==============================] - 0s 15us/sample - loss: 6917.8214 - root_mean_squared_error: 83.1734 - val_loss: 7402.0493 - val_root_mean_squared_error: 86.0352
# Epoch 22/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 6916.7572 - root_mean_squared_error: 83.1670 - val_loss: 7403.3648 - val_root_mean_squared_error: 86.0428
# Epoch 23/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6918.2435 - root_mean_squared_error: 83.1760 - val_loss: 7403.6539 - val_root_mean_squared_error: 86.0445
# Epoch 24/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.7183 - root_mean_squared_error: 83.1728 - val_loss: 7404.1108 - val_root_mean_squared_error: 86.0471
# Epoch 25/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6918.0672 - root_mean_squared_error: 83.1749 - val_loss: 7402.6458 - val_root_mean_squared_error: 86.0386
# Epoch 26/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.3061 - root_mean_squared_error: 83.1704 - val_loss: 7402.3242 - val_root_mean_squared_error: 86.0368
# Epoch 27/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.4921 - root_mean_squared_error: 83.1714 - val_loss: 7406.0871 - val_root_mean_squared_error: 86.0586
# Epoch 28/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.1304 - root_mean_squared_error: 83.1693 - val_loss: 7402.3162 - val_root_mean_squared_error: 86.0367
# Epoch 29/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6918.0169 - root_mean_squared_error: 83.1746 - val_loss: 7406.4483 - val_root_mean_squared_error: 86.0607
# Epoch 30/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.4636 - root_mean_squared_error: 83.1713 - val_loss: 7403.4824 - val_root_mean_squared_error: 86.0435
# Epoch 31/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.5302 - root_mean_squared_error: 83.1717 - val_loss: 7407.7203 - val_root_mean_squared_error: 86.0681
# Epoch 32/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.0373 - root_mean_squared_error: 83.1687 - val_loss: 7410.9110 - val_root_mean_squared_error: 86.0866
# Epoch 33/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6918.1563 - root_mean_squared_error: 83.1754 - val_loss: 7402.8412 - val_root_mean_squared_error: 86.0398
# Epoch 34/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6916.5670 - root_mean_squared_error: 83.1659 - val_loss: 7409.9377 - val_root_mean_squared_error: 86.0810
# Epoch 35/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.3247 - root_mean_squared_error: 83.1705 - val_loss: 7404.5154 - val_root_mean_squared_error: 86.0495
# Epoch 36/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.7033 - root_mean_squared_error: 83.1727 - val_loss: 7409.8835 - val_root_mean_squared_error: 86.0807
# Epoch 37/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6918.2670 - root_mean_squared_error: 83.1761 - val_loss: 7403.9608 - val_root_mean_squared_error: 86.0463
# Epoch 38/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.9725 - root_mean_squared_error: 83.1743 - val_loss: 7407.4666 - val_root_mean_squared_error: 86.0666
# Epoch 39/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.5132 - root_mean_squared_error: 83.1716 - val_loss: 7402.9867 - val_root_mean_squared_error: 86.0406
# Epoch 40/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6918.4697 - root_mean_squared_error: 83.1773 - val_loss: 7406.6414 - val_root_mean_squared_error: 86.0618
# Epoch 41/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6918.6294 - root_mean_squared_error: 83.1783 - val_loss: 7406.9831 - val_root_mean_squared_error: 86.0638
# Epoch 42/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6916.7816 - root_mean_squared_error: 83.1672 - val_loss: 7406.3589 - val_root_mean_squared_error: 86.0602
# Epoch 43/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 6916.3698 - root_mean_squared_error: 83.1647 - val_loss: 7402.5793 - val_root_mean_squared_error: 86.0382
# Epoch 44/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 6916.3026 - root_mean_squared_error: 83.1643 - val_loss: 7402.1162 - val_root_mean_squared_error: 86.0356
# Epoch 45/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.6326 - root_mean_squared_error: 83.1723 - val_loss: 7404.0251 - val_root_mean_squared_error: 86.0466
# Epoch 46/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6918.3967 - root_mean_squared_error: 83.1769 - val_loss: 7404.6468 - val_root_mean_squared_error: 86.0503
# Epoch 47/70
# 13600/13600 [==============================] - 0s 16us/sample - loss: 6918.1311 - root_mean_squared_error: 83.1753 - val_loss: 7405.2775 - val_root_mean_squared_error: 86.0539
# Epoch 48/70
# 13600/13600 [==============================] - 0s 16us/sample - loss: 6918.3955 - root_mean_squared_error: 83.1769 - val_loss: 7403.2922 - val_root_mean_squared_error: 86.0424
# Epoch 49/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.4443 - root_mean_squared_error: 83.1712 - val_loss: 7407.7419 - val_root_mean_squared_error: 86.0682
# Epoch 50/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6916.4616 - root_mean_squared_error: 83.1653 - val_loss: 7405.0000 - val_root_mean_squared_error: 86.0523
# Epoch 51/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.3815 - root_mean_squared_error: 83.1708 - val_loss: 7402.3272 - val_root_mean_squared_error: 86.0368
# Epoch 52/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.7208 - root_mean_squared_error: 83.1728 - val_loss: 7403.9889 - val_root_mean_squared_error: 86.0464
# Epoch 53/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.2585 - root_mean_squared_error: 83.1700 - val_loss: 7401.7667 - val_root_mean_squared_error: 86.0335
# Epoch 54/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.6495 - root_mean_squared_error: 83.1724 - val_loss: 7402.1558 - val_root_mean_squared_error: 86.0358
# Epoch 55/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.8541 - root_mean_squared_error: 83.1736 - val_loss: 7402.2101 - val_root_mean_squared_error: 86.0361
# Epoch 56/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.8101 - root_mean_squared_error: 83.1734 - val_loss: 7401.9854 - val_root_mean_squared_error: 86.0348
# Epoch 57/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6916.7383 - root_mean_squared_error: 83.1669 - val_loss: 7402.8832 - val_root_mean_squared_error: 86.0400
# Epoch 58/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.7269 - root_mean_squared_error: 83.1729 - val_loss: 7405.8752 - val_root_mean_squared_error: 86.0574
# Epoch 59/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.1172 - root_mean_squared_error: 83.1692 - val_loss: 7402.5345 - val_root_mean_squared_error: 86.0380
# Epoch 60/70
# 13600/13600 [==============================] - 0s 15us/sample - loss: 6918.4798 - root_mean_squared_error: 83.1774 - val_loss: 7406.0359 - val_root_mean_squared_error: 86.0583
# Epoch 61/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6918.1048 - root_mean_squared_error: 83.1751 - val_loss: 7403.8960 - val_root_mean_squared_error: 86.0459
# Epoch 62/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6916.8821 - root_mean_squared_error: 83.1678 - val_loss: 7402.3214 - val_root_mean_squared_error: 86.0367
# Epoch 63/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.8216 - root_mean_squared_error: 83.1735 - val_loss: 7402.4854 - val_root_mean_squared_error: 86.0377
# Epoch 64/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6917.0149 - root_mean_squared_error: 83.1686 - val_loss: 7408.0278 - val_root_mean_squared_error: 86.0699
# Epoch 65/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.0591 - root_mean_squared_error: 83.1689 - val_loss: 7402.6187 - val_root_mean_squared_error: 86.0385
# Epoch 66/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.3744 - root_mean_squared_error: 83.1708 - val_loss: 7402.2051 - val_root_mean_squared_error: 86.0361
# Epoch 67/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 6918.2422 - root_mean_squared_error: 83.1760 - val_loss: 7403.7257 - val_root_mean_squared_error: 86.0449
# Epoch 68/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 6917.5924 - root_mean_squared_error: 83.1721 - val_loss: 7403.4047 - val_root_mean_squared_error: 86.0430
# Epoch 69/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.0198 - root_mean_squared_error: 83.1686 - val_loss: 7402.2566 - val_root_mean_squared_error: 86.0364
# Epoch 70/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.3505 - root_mean_squared_error: 83.1706 - val_loss: 7402.1811 - val_root_mean_squared_error: 86.0359
# 81.60228

# %% [markdown]
# #### Evaluating Model Performance

# %%
evaluate(shuffled_train_df, ["median_income"], "median_house_value", 0.08, 10, 100, .2, True, test_df)
# Out:
# Train on 13600 samples, validate on 3400 samples
# Epoch 1/10
# 13600/13600 [==============================] - 0s 32us/sample - loss: 41790.0353 - root_mean_squared_error: 204.4261 - val_loss: 34107.6697 - val_root_mean_squared_error: 184.6826
# Epoch 2/10
# 13600/13600 [==============================] - 0s 11us/sample - loss: 24254.6202 - root_mean_squared_error: 155.7390 - val_loss: 18905.1736 - val_root_mean_squared_error: 137.4961
# Epoch 3/10
# 13600/13600 [==============================] - 0s 10us/sample - loss: 12971.3916 - root_mean_squared_error: 113.8920 - val_loss: 10117.9717 - val_root_mean_squared_error: 100.5881
# Epoch 4/10
# 13600/13600 [==============================] - 0s 13us/sample - loss: 7747.8784 - root_mean_squared_error: 88.0220 - val_loss: 7447.1488 - val_root_mean_squared_error: 86.2969
# Epoch 5/10
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6920.0812 - root_mean_squared_error: 83.1870 - val_loss: 7406.8706 - val_root_mean_squared_error: 86.0632
# Epoch 6/10
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6917.4392 - root_mean_squared_error: 83.1711 - val_loss: 7403.8063 - val_root_mean_squared_error: 86.0454
# Epoch 7/10
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6918.1461 - root_mean_squared_error: 83.1754 - val_loss: 7403.2449 - val_root_mean_squared_error: 86.0421
# Epoch 8/10
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6918.1203 - root_mean_squared_error: 83.1752 - val_loss: 7404.0706 - val_root_mean_squared_error: 86.0469
# Epoch 9/10
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6918.1827 - root_mean_squared_error: 83.1756 - val_loss: 7406.0300 - val_root_mean_squared_error: 86.0583
# Epoch 10/10
# 13600/13600 [==============================] - 0s 13us/sample - loss: 6917.5527 - root_mean_squared_error: 83.1718 - val_loss: 7402.8992 - val_root_mean_squared_error: 86.0401
# 72.56784
# 3000/3000 [==============================] - 0s 10us/sample - loss: 7012.6076 - root_mean_squared_error: 83.7413
# ************************
# Test Results
# ************************
# Loss: 7012.607633463542,
# RMSE: 83.7413101196289
# ************************

# %% [markdown]
# #### Creating Syntetic Data

# %% [markdown]
# To do this, we need to know what our features mean exactly.
#
# 1. **longitude:** A measure of how far west a house is; a higher value is farther west
# 2. **latitude:** A measure of how far north a house is; a higher value is farther north
# 3. **housing_median_age:** Median age of a house within a block; a lower number is a newer building
# 4. **total_rooms:** Total number of rooms within a block
# 5. **total_bedrooms:** Total number of bedrooms within a block
# 6. **population:** Total number of people residing within a block
# 7. **households:** Total number of households, a group of people residing within a home unit, for a block
# 8. **median_income:** Median income for households within a block of houses (measured in tens of thousands of US Dollars)
# 9. **median_house_value:** Median house value for households within a block (measured in US Dollars)
#
# We'll create some syntetic features and check those if they worked well or not.
# * The first feature will be the **rooms_per_person** = **total_rooms** / **population**
# * Assuming that the income is normally distributed. the median will be equal to mean. By applying this assumption we can calculate **mean_income_per_person** = (**households** x **median_income**) / **population**
# * By summing the **total_rooms** and **total_bedrooms** we can calculate the **absolute_total_rooms**
#     - by dividing this to **population** we can calculate the **absolute_rooms_per_person**
#     - by dividing this to **households** we can calculate the **absolute_rooms_per_house**

# %%
### Creating Features
combined_set = [train_df, test_df]

for df in combined_set:
    df["rooms_per_person"] = df["total_rooms"]/df["population"]
    df["mean_income_per_person"] = (df["households"]*df["median_income"])/df["population"]
    df["absolute_total_rooms"] = df["total_rooms"] + df["total_bedrooms"]
    df["absolute_rooms_per_persom"] = df["absolute_total_rooms"] / df["population"]
    df["absolute_rooms_per_house"] = df["absolute_total_rooms"] / df["households"]

# %%
train_df.corr()["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value           1.00
# mean_income_per_person       0.75
# median_income                0.69
# rooms_per_person             0.21
# absolute_rooms_per_persom    0.19
#                              ...
# households                   0.06
# total_bedrooms               0.05
# population                  -0.03
# longitude                   -0.04
# latitude                    -0.14
# Name: median_house_value, Length: 14, dtype: float64

# %%
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index))
evaluate(shuffled_train_df, ["mean_income_per_person"], "median_house_value", 0.08, 70, 100, .2, True, test_df)
# Out:
# Train on 13600 samples, validate on 3400 samples
# Epoch 1/70
# 13600/13600 [==============================] - 1s 47us/sample - loss: 49629.7220 - root_mean_squared_error: 222.7773 - val_loss: 44627.3775 - val_root_mean_squared_error: 211.2519
# Epoch 2/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 39049.6088 - root_mean_squared_error: 197.6098 - val_loss: 34715.4335 - val_root_mean_squared_error: 186.3208
# Epoch 3/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 29989.3624 - root_mean_squared_error: 173.1744 - val_loss: 26304.5977 - val_root_mean_squared_error: 162.1869
# Epoch 4/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 22470.8419 - root_mean_squared_error: 149.9028 - val_loss: 19437.7180 - val_root_mean_squared_error: 139.4192
# Epoch 5/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 16347.7199 - root_mean_squared_error: 127.8582 - val_loss: 13970.8051 - val_root_mean_squared_error: 118.1982
# Epoch 6/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 11729.8910 - root_mean_squared_error: 108.3046 - val_loss: 10007.4669 - val_root_mean_squared_error: 100.0373
# Epoch 7/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 8591.0645 - root_mean_squared_error: 92.6880 - val_loss: 7521.6341 - val_root_mean_squared_error: 86.7273
# Epoch 8/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6851.4636 - root_mean_squared_error: 82.7736 - val_loss: 6407.2390 - val_root_mean_squared_error: 80.0452
# Epoch 9/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6321.0453 - root_mean_squared_error: 79.5050 - val_loss: 6167.8956 - val_root_mean_squared_error: 78.5359
# Epoch 10/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6192.3631 - root_mean_squared_error: 78.6916 - val_loss: 6063.6725 - val_root_mean_squared_error: 77.8696
# Epoch 11/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6111.6068 - root_mean_squared_error: 78.1768 - val_loss: 5986.9023 - val_root_mean_squared_error: 77.3751
# Epoch 12/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6056.4224 - root_mean_squared_error: 77.8230 - val_loss: 5932.0848 - val_root_mean_squared_error: 77.0200
# Epoch 13/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6013.7433 - root_mean_squared_error: 77.5483 - val_loss: 5891.6835 - val_root_mean_squared_error: 76.7573
# Epoch 14/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5985.8450 - root_mean_squared_error: 77.3683 - val_loss: 5863.1310 - val_root_mean_squared_error: 76.5711
# Epoch 15/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5964.6357 - root_mean_squared_error: 77.2310 - val_loss: 5840.8535 - val_root_mean_squared_error: 76.4255
# Epoch 16/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5949.4166 - root_mean_squared_error: 77.1325 - val_loss: 5824.0175 - val_root_mean_squared_error: 76.3153
# Epoch 17/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5940.0803 - root_mean_squared_error: 77.0719 - val_loss: 5812.8844 - val_root_mean_squared_error: 76.2423
# Epoch 18/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5932.9544 - root_mean_squared_error: 77.0257 - val_loss: 5803.8887 - val_root_mean_squared_error: 76.1833
# Epoch 19/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5926.7905 - root_mean_squared_error: 76.9856 - val_loss: 5801.8936 - val_root_mean_squared_error: 76.1702
# Epoch 20/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5921.0986 - root_mean_squared_error: 76.9487 - val_loss: 5790.5644 - val_root_mean_squared_error: 76.0958
# Epoch 21/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5921.4410 - root_mean_squared_error: 76.9509 - val_loss: 5789.4380 - val_root_mean_squared_error: 76.0884
# Epoch 22/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5919.5177 - root_mean_squared_error: 76.9384 - val_loss: 5786.2383 - val_root_mean_squared_error: 76.0673
# Epoch 23/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 5918.5362 - root_mean_squared_error: 76.9320 - val_loss: 5783.6519 - val_root_mean_squared_error: 76.0503
# Epoch 24/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 5917.5323 - root_mean_squared_error: 76.9255 - val_loss: 5781.1781 - val_root_mean_squared_error: 76.0341
# Epoch 25/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 5915.5352 - root_mean_squared_error: 76.9125 - val_loss: 5779.8113 - val_root_mean_squared_error: 76.0251
# Epoch 26/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 5917.6090 - root_mean_squared_error: 76.9260 - val_loss: 5779.6546 - val_root_mean_squared_error: 76.0240
# Epoch 27/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.2825 - root_mean_squared_error: 76.9174 - val_loss: 5782.2311 - val_root_mean_squared_error: 76.0410
# Epoch 28/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 5917.0005 - root_mean_squared_error: 76.9220 - val_loss: 5779.1413 - val_root_mean_squared_error: 76.0207
# Epoch 29/70
# 13600/13600 [==============================] - 0s 15us/sample - loss: 5916.7415 - root_mean_squared_error: 76.9204 - val_loss: 5777.4311 - val_root_mean_squared_error: 76.0094
# Epoch 30/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.4812 - root_mean_squared_error: 76.9187 - val_loss: 5777.0976 - val_root_mean_squared_error: 76.0072
# Epoch 31/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5916.8651 - root_mean_squared_error: 76.9212 - val_loss: 5777.5055 - val_root_mean_squared_error: 76.0099
# Epoch 32/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.1380 - root_mean_squared_error: 76.9164 - val_loss: 5777.9253 - val_root_mean_squared_error: 76.0127
# Epoch 33/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.3477 - root_mean_squared_error: 76.9178 - val_loss: 5776.8500 - val_root_mean_squared_error: 76.0056
# Epoch 34/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5916.3221 - root_mean_squared_error: 76.9176 - val_loss: 5776.2836 - val_root_mean_squared_error: 76.0019
# Epoch 35/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5916.6174 - root_mean_squared_error: 76.9196 - val_loss: 5776.4374 - val_root_mean_squared_error: 76.0029
# Epoch 36/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 5916.4239 - root_mean_squared_error: 76.9183 - val_loss: 5777.9156 - val_root_mean_squared_error: 76.0126
# Epoch 37/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 5916.6246 - root_mean_squared_error: 76.9196 - val_loss: 5776.9092 - val_root_mean_squared_error: 76.0060
# Epoch 38/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5915.8562 - root_mean_squared_error: 76.9146 - val_loss: 5780.8606 - val_root_mean_squared_error: 76.0320
# Epoch 39/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5916.1988 - root_mean_squared_error: 76.9168 - val_loss: 5775.9401 - val_root_mean_squared_error: 75.9996
# Epoch 40/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.6156 - root_mean_squared_error: 76.9195 - val_loss: 5775.7142 - val_root_mean_squared_error: 75.9981
# Epoch 41/70
# 13600/13600 [==============================] - 0s 13us/sample - loss: 5916.2116 - root_mean_squared_error: 76.9169 - val_loss: 5778.7049 - val_root_mean_squared_error: 76.0178
# Epoch 42/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5916.6091 - root_mean_squared_error: 76.9195 - val_loss: 5776.8227 - val_root_mean_squared_error: 76.0054
# Epoch 43/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.0396 - root_mean_squared_error: 76.9158 - val_loss: 5774.9870 - val_root_mean_squared_error: 75.9933
# Epoch 44/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.5657 - root_mean_squared_error: 76.9192 - val_loss: 5775.7328 - val_root_mean_squared_error: 75.9982
# Epoch 45/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.6461 - root_mean_squared_error: 76.9197 - val_loss: 5776.1060 - val_root_mean_squared_error: 76.0007
# Epoch 46/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.4841 - root_mean_squared_error: 76.9187 - val_loss: 5775.4009 - val_root_mean_squared_error: 75.9961
# Epoch 47/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5916.1500 - root_mean_squared_error: 76.9165 - val_loss: 5774.6941 - val_root_mean_squared_error: 75.9914
# Epoch 48/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.5114 - root_mean_squared_error: 76.9189 - val_loss: 5775.1234 - val_root_mean_squared_error: 75.9942
# Epoch 49/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.4859 - root_mean_squared_error: 76.9187 - val_loss: 5774.9905 - val_root_mean_squared_error: 75.9934
# Epoch 50/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.4896 - root_mean_squared_error: 76.9187 - val_loss: 5777.4776 - val_root_mean_squared_error: 76.0097
# Epoch 51/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5915.7258 - root_mean_squared_error: 76.9137 - val_loss: 5781.3545 - val_root_mean_squared_error: 76.0352
# Epoch 52/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.5920 - root_mean_squared_error: 76.9194 - val_loss: 5777.6344 - val_root_mean_squared_error: 76.0107
# Epoch 53/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5915.5994 - root_mean_squared_error: 76.9129 - val_loss: 5775.9165 - val_root_mean_squared_error: 75.9995
# Epoch 54/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.4323 - root_mean_squared_error: 76.9184 - val_loss: 5774.5387 - val_root_mean_squared_error: 75.9904
# Epoch 55/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5915.7969 - root_mean_squared_error: 76.9142 - val_loss: 5774.2216 - val_root_mean_squared_error: 75.9883
# Epoch 56/70
# 13600/13600 [==============================] - 0s 15us/sample - loss: 5916.7633 - root_mean_squared_error: 76.9205 - val_loss: 5777.1625 - val_root_mean_squared_error: 76.0076
# Epoch 57/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 5915.9483 - root_mean_squared_error: 76.9152 - val_loss: 5774.7054 - val_root_mean_squared_error: 75.9915
# Epoch 58/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.6052 - root_mean_squared_error: 76.9195 - val_loss: 5776.2034 - val_root_mean_squared_error: 76.0013
# Epoch 59/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 5915.7600 - root_mean_squared_error: 76.9140 - val_loss: 5775.9581 - val_root_mean_squared_error: 75.9997
# Epoch 60/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.5003 - root_mean_squared_error: 76.9188 - val_loss: 5777.5957 - val_root_mean_squared_error: 76.0105
# Epoch 61/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.4892 - root_mean_squared_error: 76.9187 - val_loss: 5777.7537 - val_root_mean_squared_error: 76.0115
# Epoch 62/70
# 13600/13600 [==============================] - 0s 11us/sample - loss: 5916.2114 - root_mean_squared_error: 76.9169 - val_loss: 5779.2506 - val_root_mean_squared_error: 76.0214
# Epoch 63/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.7364 - root_mean_squared_error: 76.9203 - val_loss: 5776.9912 - val_root_mean_squared_error: 76.0065
# Epoch 64/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.2573 - root_mean_squared_error: 76.9172 - val_loss: 5777.0771 - val_root_mean_squared_error: 76.0071
# Epoch 65/70
# 13600/13600 [==============================] - 0s 14us/sample - loss: 5916.5058 - root_mean_squared_error: 76.9188 - val_loss: 5776.2011 - val_root_mean_squared_error: 76.0013
# Epoch 66/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.4572 - root_mean_squared_error: 76.9185 - val_loss: 5775.9476 - val_root_mean_squared_error: 75.9997
# Epoch 67/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.6393 - root_mean_squared_error: 76.9197 - val_loss: 5777.0587 - val_root_mean_squared_error: 76.0070
# Epoch 68/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5916.2770 - root_mean_squared_error: 76.9173 - val_loss: 5775.1682 - val_root_mean_squared_error: 75.9945
# Epoch 69/70
# 13600/13600 [==============================] - 0s 12us/sample - loss: 5915.5745 - root_mean_squared_error: 76.9128 - val_loss: 5778.1307 - val_root_mean_squared_error: 76.0140
# Epoch 70/70
# 13600/13600 [==============================] - 0s 16us/sample - loss: 5914.1303 - root_mean_squared_error: 76.9034 - val_loss: 5774.7990 - val_root_mean_squared_error: 75.9921
# 121.62146
# 3000/3000 [==============================] - 0s 7us/sample - loss: 6043.1287 - root_mean_squared_error: 77.7376
# ************************
# Test Results
# ************************
# Loss: 6043.128719075521,
# RMSE: 77.73756408691406
# ************************

# %% [markdown]
# ---
